# %% [markdown]
# <a href="https://colab.research.google.com/github/Saulrega/FIFA/blob/main/An%C3%A1lisis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd '/content/drive/MyDrive/Portafolio/Analista/Data'
# !ls
# Out:
# /content/drive/MyDrive/Portafolio/Analista/Data
#  FIFA_clean.csv   Fraud.csv			 'Most Values Sports Team'
#  FIFA.csv	 'Most value sports team.ipynb'

# %%
df = pd.read_csv('FIFA_clean.csv')

# %%
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age Nationality  Overall  Potential  \
# 0           0  158023           L. Messi   31   Argentina       94         94
# 1           1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2           2  190871          Neymar Jr   26      Brazil       92         93
# 3           3  193080             De Gea   27       Spain       91         93
# 4           4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club  Value  Wage  ...  Composure Marking  StandingTackle  \
# 0         FC Barcelona  110.5   565  ...       96.0    33.0            28.0
# 1             Juventus   77.0   405  ...       95.0    28.0            31.0
# 2  Paris Saint-Germain  118.5   290  ...       94.0    27.0            24.0
# 3    Manchester United   72.0   260  ...       68.0    15.0            21.0
# 4      Manchester City  102.0   355  ...       88.0    68.0            58.0
#
# ...

# %%
df.drop(columns='Unnamed: 0', inplace=True)

# %%
df.describe()
# Out:
#                   ID          Age      Overall    Potential        Value  \
# count    6197.000000  6197.000000  6197.000000  6197.000000  6197.000000
# mean   206522.686138    26.176053    72.964338    76.283202     5.844279
# std     27220.468356     3.945786     4.356957     4.716357     8.327561
# min        41.000000    16.000000    64.000000    69.000000     1.000000
# 25%    192123.000000    23.000000    70.000000    73.000000     1.600000
# 50%    210214.000000    26.000000    72.000000    76.000000     3.200000
# 75%    226401.000000    29.000000    75.000000    79.000000     7.000000
# max    246239.000000    40.000000    94.000000    95.000000   118.500000
#
#               Wage      Special  International Reputation    Weak Foot  \
# count  6197.000000  6197.000000               6197.000000  6197.000000
# mean     21.513797  1769.142488                  1.282395     3.096982
# std      33.098124   227.033845                  0.595579     0.687281
# ...

# %%
plt.hist(df['Age']);

# %%
plt.boxplot(df['Value']);

# %%
df.boxplot(column= ['Overall','Potential' ]);

# %%
promesas = df.query("Age<25 and Potential >80")

# %%
promesas.head()
# Out:
#         ID       Name  Age Nationality  Overall  Potential  \
# 15  211110  P. Dybala   24   Argentina       89         94
# 16  202126    H. Kane   24     England       89         91
# 25  231747  K. Mbappé   19      France       88         95
# 40  205600  S. Umtiti   24      France       87         92
# 53  222492    L. Sané   22     Germany       86         92
#
#                    Club  Value  Wage  Special  ... Composure  Marking  \
# 15             Juventus   89.0   205     2092  ...      84.0     23.0
# 16    Tottenham Hotspur   83.5   205     2165  ...      89.0     56.0
# 25  Paris Saint-Germain   81.0   100     2118  ...      86.0     34.0
# 40         FC Barcelona   57.0   205     2147  ...      82.0     90.0
# 53      Manchester City   61.0   195     2090  ...      78.0     36.0
#
#     StandingTackle  SlidingTackle GKDiving GKHandling  GKKicking  \
# 15            20.0           20.0      5.0        4.0        4.0
# ...

# %%
plt.boxplot(promesas['Value']);

# %%
promesas.drop(promesas[promesas.Value>30].index, axis=0, inplace=True);
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
plt.boxplot(promesas['Value']);

# %%
df.boxplot(column= ['Overall','Potential' ]);

# %%
promesas
# Out:
#           ID           Name  Age  Nationality  Overall  Potential  \
# 162   213331         J. Tah   22      Germany       83         88
# 172   206585           Kepa   23        Spain       83         91
# 175   204935    J. Pickford   24      England       83         88
# 177   203574      J. Stones   24      England       83         87
# 221   235243     M. de Ligt   18  Netherlands       82         91
# ...      ...            ...  ...          ...      ...        ...
# 6184  235735      E. Ampadu   17        Wales       65         86
# 6187  236772  D. Szoboszlai   17      Hungary       65         83
# 6188  238319     T. Edwards   19      England       65         82
# 6190  228357        K. Soni   20     Cameroon       64         81
# 6194  241266    W. Geubbels   16       France       64         86
#
#                       Club  Value  Wage  Special  ... Composure  Marking  \
# 162    Bayer 04 Leverkusen   29.5    67     1673  ...      75.0     80.0
# ...

# %%
porteros = promesas.query('GKPositioning > 50')

# %%
porteros
# Out:
#           ID            Name  Age    Nationality  Overall  Potential  \
# 172   206585            Kepa   23          Spain       83         91
# 175   204935     J. Pickford   24        England       83         88
# 224   230621   G. Donnarumma   19          Italy       82         93
# 232   221087       Pau López   23          Spain       82         87
# 332   212151    T. Strakosha   23        Albania       81         86
# 418   226753        A. Onana   22       Cameroon       80         85
# 706   231691       A. Lafont   19         France       78         90
# 758   213732     A. Selikhov   24         Russia       78         82
# 786   205659       A. Cragno   24          Italy       78         84
# 908   227127     Álex Remiro   23          Spain       77         83
# 1159  211990  O. Vlachodimos   24         Greece       76         83
# 1339  211101    Rubén Blanco   22          Spain       76         83
# 1457  201976        A. Gomis   24        Senegal       76         82
# ...

# %%
promesas.drop(promesas[promesas.GKPositioning > 50].index, axis=0, inplace=True);
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
promesas
# Out:
#           ID            Name  Age  Nationality  Overall  Potential  \
# 162   213331          J. Tah   22      Germany       83         88
# 177   203574       J. Stones   24      England       83         87
# 221   235243      M. de Ligt   18  Netherlands       82         91
# 222   231866           Rodri   22        Spain       82         87
# 228   227055  Gelson Martins   23     Portugal       82         87
# ...      ...             ...  ...          ...      ...        ...
# 6184  235735       E. Ampadu   17        Wales       65         86
# 6187  236772   D. Szoboszlai   17      Hungary       65         83
# 6188  238319      T. Edwards   19      England       65         82
# 6190  228357         K. Soni   20     Cameroon       64         81
# 6194  241266     W. Geubbels   16       France       64         86
#
#                       Club  Value  Wage  Special  ... Composure  Marking  \
# 162    Bayer 04 Leverkusen   29.5    67     1673  ...      75.0     80.0
# ...

# %%
promesas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 679 entries, 162 to 6194
# Data columns (total 82 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        679 non-null    int64
#  1   Name                      679 non-null    object
#  2   Age                       679 non-null    int64
#  3   Nationality               679 non-null    object
#  4   Overall                   679 non-null    int64
#  5   Potential                 679 non-null    int64
#  6   Club                      679 non-null    object
#  7   Value                     679 non-null    float64
#  8   Wage                      679 non-null    int64
#  9   Special                   679 non-null    int64
#  10  Preferred Foot            679 non-null    object
#  11  International Reputation  679 non-null    float64
#  12  Weak Foot                 679 non-null    float64
# ...

# %%
sns.countplot(data=promesas,x='Preferred Foot')
plt.show()

# %%
sns.scatterplot(data=promesas, x='Overall', y='Value')

# %%
sns.pairplot(data=porteros[['GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes']])
